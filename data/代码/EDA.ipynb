# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# %%
for i in range(1, 5):
    display(Image.open(f"{i}.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=826x798 at 0x202BB559A48>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=822x803 at 0x202BB559208>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=828x808 at 0x202BB559048>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=822x695 at 0x202BB559F88>

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    customer_id  main_account_loan_no  main_account_active_loan_no  \
# 0       105691                     4                            3
# 1        24938                     7                            2
# 2       104389                     5                            4
# 3        54688                    43                           13
# 4        63894                     0                            0
#
#    main_account_overdue_no  main_account_outstanding_loan  \
# 0                        0                         384989
# 1                        0                         268670
# 2                        1                        3519013
# 3                        6                        1867106
# 4                        0                              0
#
#    main_account_sanction_loan  main_account_disbursed_loan  \
# 0                      666207                       666207
# 1                      387994                       387994
# ...
